# %% [markdown]
# <a href="https://colab.research.google.com/github/Lj-2013/Projeto-de-extens-o/blob/main/Extens%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
from random import randint

# %%
gastos = [randint(1500, 3500) for i in range(12)]

# %%
meses = ["janeiro", "fevereiro", "março", "abril", "maio", "junho", "julho", "agosto", "setembro", "outubro", "novembro", "dezembro"]

# %%
gastos
# Out:
# [1672, 1664, 3365, 2563, 3034, 2523, 3290, 1740, 2348, 3378, 2636, 2958]

# %%
plt.plot (meses, gastos)
